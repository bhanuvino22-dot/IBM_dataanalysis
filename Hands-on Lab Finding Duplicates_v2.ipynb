# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 145.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 168.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 154.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 148.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 97.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 173.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]
# ...

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
# df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here

duplicate_count = df.duplicated().sum()

print("Number of duplicate rows:", duplicate_count)


duplicate_rows = df[df.duplicated()]

print("\nFirst few duplicate rows:")
print(duplicate_rows.head())
# Out:
# Number of duplicate rows: 20
# First few duplicate rows:
#        ResponseId                      MainBranch                 Age  \
# 65437           1  I am a developer by profession  Under 18 years old
# 65438           2  I am a developer by profession     35-44 years old
# 65439           3  I am a developer by profession     45-54 years old
# 65440           4           I am learning to code     18-24 years old
# 65441           5  I am a developer by profession     18-24 years old
#
#                 Employment RemoteWork   Check  \
# 65437  Employed, full-time     Remote  Apples
# 65438  Employed, full-time     Remote  Apples
# 65439  Employed, full-time     Remote  Apples
# 65440   Student, full-time        NaN  Apples
# 65441   Student, full-time        NaN  Apples
#
#                                         CodingActivities  \
# 65437                                              Hobby
# 65438  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# ### Task 2: Analysis of Duplicate Response Patterns
# 1. Identify duplicate response patterns based on selected columns such as MainBranch, Employment, and RemoteWork.
# 2. Clarify that these represent multiple respondents with identical answers rather than duplicate records. Analyse which other columns frequently share identical values within these response-pattern groups.

# %%
## Write your code here
cols = ['MainBranch', 'Employment', 'RemoteWork']
duplicates = df[df.duplicated(subset=cols, keep=False)]
print(duplicates[cols].head())
print("These are not duplicate records.")
print("They are different respondents with similar answers.")
for col in df.columns:
    if col not in cols:
        same_values = duplicates.groupby(cols)[col].nunique().eq(1).sum()
        print(col, ":", same_values)
# Out:
#                        MainBranch           Employment RemoteWork
# 0  I am a developer by profession  Employed, full-time     Remote
# 1  I am a developer by profession  Employed, full-time     Remote
# 2  I am a developer by profession  Employed, full-time     Remote
# 3           I am learning to code   Student, full-time        NaN
# 4  I am a developer by profession   Student, full-time        NaN
# These are not duplicate records.
# They are different respondents with similar answers.
# ResponseId : 0
# Age : 30
# Check : 319
# CodingActivities : 1
# EdLevel : 23
# LearnCode : 12
# LearnCodeOnline : 33
# TechDoc : 58
# YearsCode : 13
# YearsCodePro : 8DevType : 18
# OrgSize : 20
# PurchaseInfluence : 28
# BuyNewTool : 7
# BuildvsBuy : 31
# TechEndorse : 8
# Country : 19
# Currency : 10
# CompTotal : 34
# LanguageHaveWorkedWith : 14
# LanguageWantToWorkWith : 22
# LanguageAdmired : 31
# DatabaseHaveWorkedWith : 36DatabaseWantToWorkWith : 42
# DatabaseAdmired : 41
# ...

# %% [markdown]
# ### Task 3: Visualize Shared Response Patterns
# 1. Create visualizations to show the distribution of shared response patterns across different categories.
# 2. Use bar charts or pie charts to represent the distribution of respondents who share identical values for MainBranch, Employment, and RemoteWork, grouped by Country and Employment.

# %%
## Write your code here
import matplotlib.pyplot as plt
shared = df.groupby(['Country', 'Employment']).size()
shared.groupby('Country').sum().sort_values(ascending=False).head(10).plot(kind='bar')


plt.title("Shared Responses by Country")
plt.ylabel("Count")
plt.show()

shared.groupby('Employment').sum().plot(kind='pie', autopct='%1.1f%%')

plt.title("Shared Responses by Employment")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Task 4: Evaluate Duplicate Handling Strategy
# 1. Analyse the dataset to determine which column(s) define record uniqueness.
# 2. Assess whether removing rows based on a subset of columns (rather than complete row duplication) is appropriate.
# Justify your decision with reference to the structure and purpose of the dataset.

# %% [raw]
# ## Write your analysis here
# Removing rows based on only a subset of columns is not appropriate because:
#
# Different respondents may have the same employment type and work arrangement.
# Deleting such rows would remove valid survey responses.
# This would reduce data accuracy and bias the analysis.

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# Step 1: Identify Duplicate Records
#
# The dataset was checked for duplicate rows using the duplicated() function in pandas.
# df.duplicated().sum()
#
# This identified rows where all column values were exactly the same.
#
# Step 2:Inspect Duplicate Rows
#
# Duplicate rows were displayed to understand their structure and confirm whether they were true duplicates.
# df[df.duplicated()].head()
#
# This helped verify that the duplicates were complete row repetitions.
#
# Step 3: Analyse Response Patterns
#
# Duplicates were also analysed using selected columns such as:
#
# df[df.duplicated(subset=['MainBranch','Employment','RemoteWork'], keep=False)]
#
# MainBranch
# Employment
# RemoteWork
# df[df.duplicated(subset=['MainBranch','Employment','RemoteWork'], keep=False)]
#
# These were not treated as duplicate records because multiple respondents can legitimately share the same answers.
#
# Step 4: Decide Duplicate Removal Strategy
#
# The dataset is a survey dataset, so:
#
# No single column uniquely identifies respondents.
# Similar answers across a few columns do not mean records are duplicated.
#
# Therefore:
#
# Only fully duplicated rows were removed.
# Rows with matching values in selected columns were retained.
#
# Step 5: Remove True Duplicates
#
# True duplicate rows were removed using:
#
# df = df.drop_duplicates()
#
# This kept only unique complete records while preserving valid respondent data.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# The dataset is a survey dataset, so there is no unique ID for each respondent.
# Different respondents can have the same answers in some columns.
# Removing rows using only a few columns may delete valid responses.
# Complete duplicate rows are more likely to be accidental repeated records.
# Therefore, only fully duplicated rows should be removed.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
